# %% [markdown]
# <a href="https://colab.research.google.com/github/laiy3571-web/115-1/blob/main/411403621_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello\nHello")
# Out:
# Hello
# Hello

# %%
print("2026","09","22",sep="/")
# Out:
# 2026/09/22

# %%
a=5
b=2.5
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
x=50000*(1+0.015)**5
print(x)
# Out:
# 53864.20019421873

# %%
a=11
b=12
print("{}\n{}".format(a,b))
# Out:
# 11
# 12

# %%
a=11.123456
print("{:.6f}".format(a))
print(f"{a}")
# Out:
# 11.123456
# 11.123456

# %%
x=float(input("請輸入數字:"))
print(type(x))
# Out:
# 請輸入數字:4464
# <class 'float'>

# %%
x=int(input("請輸入目前金幣數量:"))
y=int(input("請輸入獲得金幣數量:"))
z=x+y
print(f"任務完成！你現在有{z}枚金幣")
# Out:
# 請輸入目前金幣數量:500
# 請輸入獲得金幣數量:250
# 任務完成！你現在有750枚金幣
